# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import root_pandas
treefile1 = 'my_analysis_tau_to_21.root'
treefile2 = 'my_analysis_tau_to_23.root'
df1 = root_pandas.read_root(treefile1, key='tree')
df2 = root_pandas.read_root(treefile2, key='tree')
# Out:
# Welcome to JupyROOT 6.14/06

# %%
df2.columns
# Out:
# Index(['__experiment__', '__run__', '__event__', '__candidate__',
#        '__ncandidates__', '__weight__', 'thrust', 'M', 'tauPlusMCMode',
#        'tauMinusMCMode',
#        ...
#        'tau_1_pi_prodVertexXErr', 'tau_1_pi_prodVertexYErr',
#        'tau_1_pi_prodVertexZErr', 'tau_1_pi_theta', 'tau_1_pi_cosTheta',
#        'tau_1_pi_phi', 'tau_1_pi_charge', 'tau_1_pi_clusterE',
#        'tau_1_pi_EoverP', 'tau_1_pi_mcPDG'],
#       dtype='object', length=212)

# %%
df1.tau_0_mu_EoverP.hist(bins=100, range = (0,2))

# %%
df1.tau_1_e_EoverP.hist(bins=100, range = (0,2))

# %%
df2.tau_1_pi_EoverP.hist(bins=100, range = (0,2))

# %%
df.tau_1_e_mcPDG.hist(bins = 50)

# %%
df.tau_1_charge.hist(bins = 50)

# %%
df1.tau_0_mu_clusterE.hist(bins=50, range = (0,5))

# %%
df1.tau_1_e_clusterE.hist(bins=50, range = (0,5))

# %%
df2.tau_1_pi_clusterE.hist(bins=50, range = (0,5))

# %%
import numpy as np

# %%
hist1, _ = np.histogram(df2.hist("tau_1_pi_clusterE"), bins=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-d7b310f9e5ca> in <module>()
# ----> 1 hist1, _ = np.histogram(df2.hist("tau_1_pi_clusterE"), bins=100)
#
# /cvmfs/belle.cern.ch/sl6/externals/v01-07-01/Linux_x86_64/common/lib/python3.6/site-packages/numpy/lib/function_base.py in histogram(a, bins, range, normed, weights, density)
#     660             first_edge, last_edge = 0.0, 1.0
#     661         else:
# --> 662             first_edge, last_edge = a.min() + 0.0, a.max() + 0.0
#     663     else:
#     664         first_edge, last_edge = [mi + 0.0 for mi in range]
#
# TypeError: unsupported operand type(s) for +: 'AxesSubplot' and 'float'

# %%
hist.intrgral()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-c189a835b906> in <module>()
# ----> 1 hist.intrgral()
#
# NameError: name 'hist' is not defined

# %%
np.max(hist1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-fc905f2a076d> in <module>()
# ----> 1 np.max(hist1)
#
# NameError: name 'hist1' is not defined

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import root_pandas
treefile1 = 'tautau_mctruthsel_21.root'
df1 = root_pandas.read_root(treefile1, key='tree')
# Out:
# Welcome to JupyROOT 6.14/06

# %%
df1.tau_0_mu_EoverP.hist(bins=100, range = (0,2))

# %%
df1.tau_1_e_EoverP.hist(bins=100, range = (0,2))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import root_pandas
treefile1 = 'mcparticles.root'
df1 = root_pandas.read_root(treefile1, key='electron')
# Out:
# Welcome to JupyROOT 6.14/06

# %%
df1.columns
# Out:
# Index(['__experiment__', '__run__', '__event__', '__candidate__',
#        '__ncandidates__', '__weight__', 'p', 'px', 'py', 'pz', 'E', 'PDG',
#        'pt'],
#       dtype='object')

# %%
df1.p.hist(bins = 50, range = (0,8) )

# %%
df1.PDG.hist()

# %%
from matplotlib import pyplot as plt
import ROOT
# Out:
# Welcome to JupyROOT 6.14/06

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-2fbf98b53ab9> in <module>()
# ----> 1 import root2matplot as r2m
#
# /cvmfs/belle.cern.ch/sl6/externals/v01-07-01/Linux_x86_64/opt/root/lib/ROOT.py in _importhook(name, *args, **kwds)
#     459       except Exception:
#     460          pass
# --> 461    return _orig_ihook( name, *args, **kwds )
#     462
#     463 __builtin__.__import__ = _importhook
#
# ModuleNotFoundError: No module named 'root2matplot'

# %%
infile = ROOT.TFile("Generator.root")

# %%
infile.ls()
# Out:
# TFile**		Generator.root
#  TFile*		Generator.root
#   KEY: TH1D	nMCParticles;1	Number of MCParticles per Event
#   KEY: TH1D	pid;1	Particle code of particles
#   KEY: TH1D	momentum;1	Momentum of particles
#   KEY: TH1D	pt;1	Transverse Momentum of particles
#   KEY: TH1D	theta;1	Polar angle of particles
#   KEY: TH1D	costheta;1	Cosinus of the polar angle of particles
#   KEY: TH1D	phi;1	Azimuth angle of particles
#   KEY: TH1D	Xmomentum;1	X axis Momentum of particles
#   KEY: TH1D	Ymomentum;1	Y axis Momentum of particles
#   KEY: TH1D	Zmomentum;1	Z axis Momentum of particles
#   KEY: TH1D	Energy;1	Energy of particles
#   KEY: TH2D	xyvertex;1	XY Vertex of particles

# %%
h = infile.Get("pid")

# %%
h.Draw()
# Out:
# Info in <TCanvas::MakeDefCanvas>:  created default TCanvas with name c1

# %%
plt.show()

# %%
c1 = ROOT.TCanvas()

# %%
h.Draw()

# %%
c1.Draw()

# %%
from matplotlib import pyplot as plt
import ROOT
infile1 = ROOT.TFile("Generator_all.root")
c2 = ROOT.TCanvas()
h1 = infile1.Get("Energy")
h1.Draw()
c2.Draw()

# %%
from matplotlib import pyplot as plt
import ROOT
infile1 = ROOT.TFile("Generator_2.root")
c2 = ROOT.TCanvas()
h1 = infile1.Get("Energy")
h1.Draw()
c2.Draw()

# %%
from matplotlib import pyplot as plt
import ROOT
infile1 = ROOT.TFile("Generator_3.root")
c2 = ROOT.TCanvas()
h1 = infile1.Get("Energy")
h1.Draw()
c2.Draw()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import root_pandas
treefile1 = 'tau_Generator_analysis_test.root'
df1 = root_pandas.read_root(treefile1, key='tree')
# Out:
# Welcome to JupyROOT 6.14/06

# %%
df1.columns
# Out:
# Index(['__experiment__', '__run__', '__event__', '__candidate__',
#        '__ncandidates__', '__weight__', 'thrust', 'M', 'tauPlusMCMode',
#        'tauMinusMCMode', 'tau_0_p', 'tau_0_px', 'tau_0_py', 'tau_0_pz',
#        'tau_0_E', 'tau_0_PDG', 'tau_0_pt', 'tau_0_M', 'tau_0_EoverP',
#        'tau_0_clusterEoP', 'tau_0_charge', 'tau_1_p', 'tau_1_px', 'tau_1_py',
#        'tau_1_pz', 'tau_1_E', 'tau_1_PDG', 'tau_1_pt', 'tau_1_M',
#        'tau_1_EoverP', 'tau_1_clusterEoP', 'tau_1_charge', 'tau_0_e_px',
#        'tau_0_e_py', 'tau_0_e_pz', 'tau_0_e_pt', 'tau_0_e_p', 'tau_0_e_E',
#        'tau_1_e_px', 'tau_1_e_py', 'tau_1_e_pz', 'tau_1_e_pt', 'tau_1_e_p',
#        'tau_1_e_E'],
#       dtype='object')

# %%
df1.tauMinusMCMode.hist()

# %%
df1.tauPlusMCMode.hist(bins =100, range = (0,10))

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-3c3da2d62376> in <module>()
# ----> 1 ax = df.plot.barh(x='lab', y='val')
#
# AttributeError: 'function' object has no attribute 'barh'
