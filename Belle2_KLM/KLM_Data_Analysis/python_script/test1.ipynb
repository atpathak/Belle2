# %%
import ROOT

# %matplotlib inline
# Out:
# Welcome to JupyROOT 6.14/06

# %%
my_file = ROOT.TFile.Open("klmHistsE-e0010r01924.root")
ROOT.gStyle.SetOptStat(10)

# %%
my_file.ls()
# Out:
# TFile**		klmHistsE-e0010r01924.root
#  TFile*		klmHistsE-e0010r01924.root
#   KEY: TDirectoryFile	RawKLM;1	RawKLM
#   KEY: TDirectoryFile	SectorOccupancy;1	SectorOccupancy
#   KEY: TDirectoryFile	LayerOccupancy;1	LayerOccupancy
#   KEY: TDirectoryFile	RPCTime;1	RPCTime
#   KEY: TDirectoryFile	ScintTime;1	ScintTime
#   KEY: TDirectoryFile	TimeDistribution;1	TimeDistribution
#   KEY: TDirectoryFile	ZHit;1	ZHit
#   KEY: TDirectoryFile	PhiHit;1	PhiHit
#   KEY: TDirectoryFile	BKLMXYOccupancy;1	BKLMXYOccupancy
#   KEY: TDirectoryFile	EKLMXYOccupancy;1	EKLMXYOccupancy

# %%
c2 = ROOT.TCanvas()

# %%
h2 = my_file.Get("PhiHit/PlanePhiStripBF6")
#h1.SetTitle("Time Distribution")
#h1.GetXaxis().SetTitle("t - trigger time")

# %%
h2.Draw("colz")
#c2.SetLogy()

# %%
c2.Draw()

# %%
c2= ROOT.TCanvas()
h2 = my_file.Get("occupancyForwardXY_L01")
h2.Draw("colz")
c2.Draw()

# %%
c3= ROOT.TCanvas()
h3 = my_file.Get("LayeroccupancyBackward")
h3.Draw()
c3.Draw()

# %%
my_file = ROOT.TFile.Open("bklmHitmap_run3123.root")
ROOT.gStyle.SetOptStat(10)

# %%
my_file.ls()
# Out:
# TFile**		bklmHitmap_run3123.root
#  TFile*		bklmHitmap_run3123.root
#   KEY: TTree	extraInfo;1	Extra informations
#   KEY: TH2F	SectLayBF;1	BF Hitmap -- run3123
#   KEY: TH2F	SectLayPlaneZBF;1	BF Hitmap of plane z -- run3123
#   KEY: TH1F	LayerBF0;1	BF0 Layer -- run3123
#   KEY: TH2F	PlaneZBF0;1	BF0 Plane z, electronic channels -- run3123
#   KEY: TH2F	PlaneZStripBF0;1	BF0 Plane z, strips -- run3123
#   KEY: TH1F	SciTdcBF0;1	BF0 TDC (Scintillators) -- run3123
#   KEY: TH1F	SciCTimeDiffBF0;1	BF0 CTime diff. (Scintillators) -- run3123
#   KEY: TH1F	LayerBF1;1	BF1 Layer -- run3123
#   KEY: TH2F	PlaneZBF1;1	BF1 Plane z, electronic channels -- run3123
#   KEY: TH2F	PlaneZStripBF1;1	BF1 Plane z, strips -- run3123
#   KEY: TH1F	SciTdcBF1;1	BF1 TDC (Scintillators) -- run3123
#   KEY: TH1F	SciCTimeDiffBF1;1	BF1 CTime diff. (Scintillators) -- run3123
#   KEY: TH1F	LayerBF2;1	BF2 Layer -- run3123
#   KEY: TH2F	PlaneZBF2;1	BF2 Plane z, electronic channels -- run3123
# ...

# %%
c2= ROOT.TCanvas()
h2 = my_file.Get("PlaneZStripBB0")
h2.GetYaxis().SetTitleOffset(1)
h2.Draw("colz")
c2.Draw()

# %%
my_file = ROOT.TFile.Open("eklmHists-e0009r00386.root")
ROOT.gStyle.SetOptStat(10)

# %%
my_file.ls()
# Out:
# TFile**		eklmHists-e0009r00386.root
#  TFile*		eklmHists-e0009r00386.root
#   KEY: TH1F	NDigitEKLM;1	e09r386: # of EKLMDigits
#   KEY: TH1F	NHit2dEKLM;1	e09r386: # of EKLMHit2ds
#   KEY: TH1F	EKLMBackwardSectorOccupancy;1	e09r386: Backward Endcap Sector occupancy of channels
#   KEY: TH1F	EKLMForwardSectorOccupancy;1	e09r386: Forward Endcap Sector occupancy of channels
#   KEY: TH2F	EKLMBackwardSectorbyctime;1	e09r386: Backward Endcap Sector occupancy of channels
#   KEY: TH2F	EKLMForwardSectorbyctime;1	e09r386: Forward Endcap Sector occupancy of channels
#   KEY: TH1F	EKLMctime;1	e09r386: CTime time
#   KEY: TH1F	EKLMtdc;1	e09r386: TDC time
#   KEY: TH1F	EndcapOccupancy;1	e09r386: Endcap occupancy of channels
#   KEY: TH2F	EKLMoccupancyForwardXY;1	e09r386: Forward Endcap XY Occupancy for total hits
#   KEY: TH2F	EKLMoccupancyBackwardXY;1	e09r386: Backward Endcap XY Occupancy for total hits
# ...

# %%
c2= ROOT.TCanvas()
h2 = my_file.Get("NDigitEKLM")
h2.Draw()
#c1.SetLogy()
c2.Draw()

# %%
my_file2 = ROOT.TFile.Open("bklmHists-e0010r00833_corrected.root")
ROOT.gStyle.SetOptStat(10)

# %%
my_file2.ls()
# Out:
# TFile**		bklmHists-e0010r00833_corrected.root
#  TFile*		bklmHists-e0010r00833_corrected.root
#   KEY: TH1F	NDigit;1	e10r833: # of BKLMDigits
#   KEY: TH1F	NRawKLM;1	e10r833: # of RawKLMs
#   KEY: TH1F	RawKLMnumEvents;1	e10r833: RawKLM NumEvents
#   KEY: TH1F	RawKLMnumNodes;1	e10r833: RawKLM NumNodes
#   KEY: TH2F	RawKLMnodeID;1	e10r833: RawKLM NodeID
#   KEY: TH2F	rawKLMlaneFlag;1	e10r833: RawKLM lane vs flag
#   KEY: TH2F	rawKLMtdcExtraRPC;1	e10r833: RawKLM RPC tdcExtra bits
#   KEY: TH2F	rawKLMadcExtraRPC;1	e10r833: RawKLM RPC adcExtra bits
#   KEY: TH2F	rawKLMtdcExtraScint;1	e10r833: RawKLM Scint tdcExtra bits
#   KEY: TH2F	rawKLMadcExtraScint;1	e10r833: RawKLM Scint adcExtra bits
#   KEY: TH1F	rawKLMsizeMultihit;1	e10r833: RawKLM word count (N/channel)
#   KEY: TH1F	rawKLMsize;1	e10r833: RawKLM word count (1/channel)
#   KEY: TH1F	rawKLM_S00_sizeMultihit;1	e10r833: sector 0 [COPPER 3 finesse 2] word count (N/channel)
# ...

# %%
c5= ROOT.TCanvas()
h5 = my_file2.Get("occupancyBackwardXYPromptBkgd")
h5.Draw("colz")
#c1.SetLogy()
c5.Draw()

# %%
my_file3 = ROOT.TFile.Open("bklmHitmap_run579.root")
ROOT.gStyle.SetOptStat(10)

# %%
my_file3.ls()
# Out:
# TFile**		bklmHitmap_run579.root
#  TFile*		bklmHitmap_run579.root
#   KEY: TTree	extraInfo;1	Extra informations
#   KEY: TH2F	SectLayBF;1	BF Hitmap -- run579
#   KEY: TH2F	SectLayPlaneZBF;1	BF Hitmap of plane z -- run579
#   KEY: TH1F	LayerBF0;1	BF0 Layer -- run579
#   KEY: TH2F	PlaneZBF0;1	BF0 Plane z, electronic channels -- run579
#   KEY: TH2F	PlaneZStripBF0;1	BF0 Plane z, strips -- run579
#   KEY: TH1F	SciTdcBF0;1	BF0 TDC (Scintillators) -- run579
#   KEY: TH1F	SciCTimeDiffBF0;1	BF0 CTime diff. (Scintillators) -- run579
#   KEY: TH1F	LayerBF1;1	BF1 Layer -- run579
#   KEY: TH2F	PlaneZBF1;1	BF1 Plane z, electronic channels -- run579
#   KEY: TH2F	PlaneZStripBF1;1	BF1 Plane z, strips -- run579
#   KEY: TH1F	SciTdcBF1;1	BF1 TDC (Scintillators) -- run579
#   KEY: TH1F	SciCTimeDiffBF1;1	BF1 CTime diff. (Scintillators) -- run579
#   KEY: TH1F	LayerBF2;1	BF2 Layer -- run579
#   KEY: TH2F	PlaneZBF2;1	BF2 Plane z, electronic channels -- run579
# ...

# %%
c6= ROOT.TCanvas()
h6 = my_file3.Get("PlaneZStripBF5")
h6.GetYaxis().SetTitleOffset(1)
h6.Draw("colz")
c6.Draw()

# %%
my_file10 = ROOT.TFile.Open("klmHists-e0008r03123.root")
#ROOT.gStyle.SetOptStat(10)

# %%
my_file10.ls()
# Out:
# TFile**		klmHists-e0008r03123.root
#  TFile*		klmHists-e0008r03123.root
#   KEY: TDirectoryFile	RawKLM;1	RawKLM
#   KEY: TDirectoryFile	SectorOccupancy;1	SectorOccupancy
#   KEY: TDirectoryFile	LayerOccupancy;1	LayerOccupancy
#   KEY: TDirectoryFile	RPCTime;1	RPCTime
#   KEY: TDirectoryFile	ScintTime;1	ScintTime
#   KEY: TDirectoryFile	TimeDistribution;1	TimeDistribution
#   KEY: TDirectoryFile	ZHit;1	ZHit
#   KEY: TDirectoryFile	PhiHit;1	PhiHit
#   KEY: TDirectoryFile	BKLMXYOccupancy;1	BKLMXYOccupancy
#   KEY: TDirectoryFile	EKLMXYOccupancy;1	EKLMXYOccupancy

# %%
#ROOT.gROOT.ForceStyle()
#ROOT.gStyle.SetOptStat(1111)
c13= ROOT.TCanvas()
h13 = my_file10.Get("RawKLM/RawKLMnodeID")
#h13.SetMaximum(2*h13.GetMaximum())
#h10.GetYaxis().SetTitleOffset(0)
#h10.SetTitle("RawKLMnodeID")
h13.GetYaxis().SetRangeUser(0.,30.)
#stats1 = h12.GetListOfFunctions().FindObject("stats")
#stats1.SetX1NDC(.4)
#stats1.SetX2NDC(.6)
#stats1.SetY1NDC(.7)
#stats1.SetY2NDC(.9)
h13.Draw("colz")
c13.Draw()
