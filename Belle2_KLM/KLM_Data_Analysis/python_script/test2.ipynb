# %%
import ROOT

# %matplotlib inline

# %%
my_file = ROOT.TFile.Open("bklmHists-e0010r01924_corrected.root")
#ROOT.gStyle.SetOptStat(10)

# %%
my_file.ls()
# Out:
# TFile**		bklmHists-e0010r01924_corrected.root
#  TFile*		bklmHists-e0010r01924_corrected.root
#   KEY: TH1F	NDigit;1	e10r1924: # of BKLMDigits
#   KEY: TH1F	NRawKLM;1	e10r1924: # of RawKLMs
#   KEY: TH1F	RawKLMnumEvents;1	e10r1924: RawKLM NumEvents
#   KEY: TH1F	RawKLMnumNodes;1	e10r1924: RawKLM NumNodes
#   KEY: TH2F	RawKLMnodeID;1	e10r1924: RawKLM NodeID
#   KEY: TH2F	rawKLMlaneFlag;1	e10r1924: RawKLM lane vs flag
#   KEY: TH2F	rawKLMtdcExtraRPC;1	e10r1924: RawKLM RPC tdcExtra bits
#   KEY: TH2F	rawKLMadcExtraRPC;1	e10r1924: RawKLM RPC adcExtra bits
#   KEY: TH2F	rawKLMtdcExtraScint;1	e10r1924: RawKLM Scint tdcExtra bits
#   KEY: TH2F	rawKLMadcExtraScint;1	e10r1924: RawKLM Scint adcExtra bits
#   KEY: TH1F	rawKLMsizeMultihit;1	e10r1924: RawKLM word count (N/channel)
#   KEY: TH1F	rawKLMsize;1	e10r1924: RawKLM word count (1/channel)
#   KEY: TH1F	rawKLM_S00_sizeMultihit;1	e10r1924: sector 0 [COPPER 3 finesse 2] word count (N/channel)
# ...

# %%
c1 = ROOT.TCanvas()
h1 = my_file.Get("NDigit")
#h1.SetMinimum(.00001 * h1.GetEntries())
#h1.SetMaximum(2*h1.GetMaximum())
#print(h4.GetMinimum())
h1.Draw()
c1.SetLogy()
c1.Draw()

# %%
c2 = ROOT.TCanvas()
h2 = my_file.Get("NDigit")
#h1.SetMinimum(.00001 * h1.GetEntries())
#h1.SetMaximum(2*h1.GetMaximum())
#print(h4.GetMinimum())
h2.Draw()
c2.SetLogy()
c2.Draw()

# %%
c2 = ROOT.TCanvas()
h2 = my_file.Get("XYOccupancy/EKLMoccupancyForwardXY")
h2.Draw("colz")
c2.Draw()
# Out:
# ---------------------------------------------------------------------------
# ReferenceError                            Traceback (most recent call last)
# <ipython-input-9-6998002c3b7c> in <module>()
#       1 c2 = ROOT.TCanvas()
#       2 h2 = my_file.Get("XYOccupancy/EKLMoccupancyForwardXY")
# ----> 3 h2.Draw("colz")
#       4 c2.Draw()
#
# ReferenceError: attempt to access a null-pointer
